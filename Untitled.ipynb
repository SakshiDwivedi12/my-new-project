# %%
print("hello sakshi")
# Out:
# hello sakshi

# %%
x=[2,4,6]
x.pop(1)
x
# Out:
# [2, 6]

# %%
x=[2,4,6]
x.remove(6)
x
# Out:
# [2, 4]

# %%
x=[2,4,6]
x.reverse(1)
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 x=[2,4,6]
# ----> 2 x.reverse(1)
#       3 x
#
# TypeError: list.reverse() takes no arguments (1 given)

# %%
x=[2,4,6]
x.reverse()
x
# Out:
# [6, 4, 2]

# %%
x=[2,4,6]
x.sort()
x
# Out:
# [2, 4, 6]

# %%
x=[2,4,6]
x.sort(4)
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 x=[2,4,6]
# ----> 2 x.sort(4)
#       3 x
#
# TypeError: sort() takes no positional arguments

# %%
x=[4,3,6]
x.sort()
x
# Out:
# [3, 4, 6]

# %%
x=[2,4,6]
x.index()
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 x=[2,4,6]
# ----> 2 x.index()
#       3 x
#
# TypeError: index expected at least 1 argument, got 0

# %%
x=[2,4,6]
x.index(3)
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 x=[2,4,6]
# ----> 2 x.index(3)
#       3 x
#
# ValueError: 3 is not in list

# %%
x=[2,4,6]
x.index()
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 x=[2,4,6]
# ----> 2 x.index()
#       3 x
#
# TypeError: index expected at least 1 argument, got 0

# %%
x=[2,4,4,6]
x.count(4)
x
# Out:
# [2, 4, 4, 6]

# %%
x=[2,4,,6]
x.count(4)
x
# Out:
#   Cell In[12], line 1
#     x=[2,4,,6]
#            ^
# SyntaxError: invalid syntax

# %%
x=[2,4,6]
x.count(4)
x
# Out:
# [2, 4, 6]

# %%
x=[2,4,6]
x.clear()
x
# Out:
# []

# %%
x=[2,4,6]
x.copy()
x
# Out:
# [2, 4, 6]

# %%
x=[2,4,6]
x.index(4)
x
# Out:
# [2, 4, 6]

# %%
x=[2,4,6]
x.index(4)
x.index(4)
# Out:
# 1

# %%
x=[2,4,4,6]
x.count(4)
y=x.count(4)
y
# Out:
# 2

# %%
num=int(input("Enter a large number"))
if num>4000:
    print("good number!")
elif num>2000:
    print("Think higher")
else:
    print("it's a small number")
# Out:
# Enter a large number 65
# it's a small number

# %%
"val" * 5
# Out:
# 'valvalvalvalval'

# %%
num=int(input("Enter a large number"))
if num>4000:
    print("good number!")
elif num>2000:
    print("Think higher")
else:
    print("it's a small number")
# Out:
# Enter a large number 54678
# good number!

# %%
num=int(input("Enter a large number"))
if num>4000:
    print("good number!")
elif num>2000:
    print("Think higher")
elif num>1000:
    print("try again")
elif num>500:
    print("again")
else:
    print("it's a small number")
# Out:
# Enter a large number 56
# it's a small number

# %%
for i in range(5):
    print("APSU")
# Out:
# APSU
# APSU
# APSU
# APSU
# APSU

# %%
for i in range(2,5):
    print("APSU")
# Out:
# APSU
# APSU
# APSU

# %%
for i in (54,87,65):
    print(i)
# Out:
# 54
# 87
# 65

# %%
for i in range(2,5):
    print(i)
# Out:
# 2
# 3
# 4

# %%
for _ in range(1,5):
    print(_)
# Out:
# 1
# 2
# 3
# 4

# %%
print(_)
# Out:
# 4

# %%
names=["TOM","DICK","HARRY"]
for names in names:
    print(names)
# Out:
# TOM
# DICK
# HARRY

# %%
def area(l,b):
    return l*b

print(area(2,3))
print(area(8,9))
# Out:
# 6
# 72

# %%
def area(l,b):
    return l*b
def display():
  print("WOW!")
        
display()
print(area(2,3))
print(area(8,9))
# Out:
# WOW!
# 6
# 72

# %%
squares=[x**2 for x in range(1,6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
r_nums=range(200,500,50)
print(r_nums)
# Out:
# range(200, 500, 50)

# %%
for r in range(200,500,50):
    print(r)
# Out:
# 200
# 250
# 300
# 350
# 400
# 450

# %%
squares=[(lambda x:x**2)(x) for x in range(1,6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
check=lambda x: "Even" if x%2==0 else "Odd"

nums=[65,51,8,66,9,6]

for num in nums:
    results=check(num)
    print(results)
# Out:
# Odd
# Odd
# Even
# Even
# Odd
# Even

# %%
data=[(4,3),(8,7),(6,1)]
sorted_result=sorted(data, key= lambda x:x[0])
print(sorted_result)
# Out:
# [(4, 3), (6, 1), (8, 7)]

# %%
data=[(4,3),(8,7),(6,1)]
sorted_result=sorted(data, key= lambda x:x[1])
print(sorted_result)
# Out:
# [(6, 1), (4, 3), (8, 7)]

# %%
data=[(4,3,8),(8,7,13),(6,1,78),(8,5,3)]
sorted_result=sorted(data, key= lambda x:x[2])
print(sorted_result)
# Out:
# [(8, 5, 3), (4, 3, 8), (8, 7, 13), (6, 1, 78)]

# %%
import pandas as pd

data = {'A': [8, 654, 899, None, 989], 'B': [984, None, None, 7, 99]}

df = pd.DataFrame(data)
print(df)
# Out:
#        A      B
# 0    8.0  984.0
# 1  654.0    NaN
# 2  899.0    NaN
# 3    NaN    7.0
# 4  989.0   99.0

# %%
import pandas as pd

data = {'A': [8, 654, 899, None, 989], 'B': [984, None, None, 7, 99]}

df = pd.DataFrame(data)
print(df)
# Out:
#        A      B
# 0    8.0  984.0
# 1  654.0    NaN
# 2  899.0    NaN
# 3    NaN    7.0
# 4  989.0   99.0

# %%
import pandas as pd

data = {'A': [8, 654, 899, None, 989], 'B': [984, None, None, 7, 99]}

df = pd.DataFrame(data)
print(df)
# Out:
#        A      B
# 0    8.0  984.0
# 1  654.0    NaN
# 2  899.0    NaN
# 3    NaN    7.0
# 4  989.0   99.0

# %%
import pandas as pd

# Assuming you have a DataFrame with a column named 'Height'
data = {'Height': [170, 160, 180, 155]}
df = pd.DataFrame(data)

# Your scheme for replacing values
scheme = {'Tall': 3, 'Medium': 2, 'Short': 1}

# Replace values in the 'Height' column using the scheme
df['Height'] = df['Height'].replace(scheme)

# Display the updated DataFrame
print(df)
# Out:
#    Height
# 0     170
# 1     160
# 2     180
# 3     155

# %%
import pandas as pd 
from sklearn.model_selection import train _test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
# Out:
#   Cell In[8], line 2
#     from sklearn.model_selection import train _test_split
#                                               ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#    Height
# 0     170
# 1     160
# 2     180
# 3     155

# %%
import pandas as pd

data = {'A': [8, 654, 899, None, 989], 'B': [984, None, None, 7, 99]}

df = pd.DataFrame(data)
print(df)
# Out:
#        A      B
# 0    8.0  984.0
# 1  654.0    NaN
# 2  899.0    NaN
# 3    NaN    7.0
# 4  989.0   99.0

# %%
df=pd.DataFrame(data)
df
# Out:
#        A      B
# 0    8.0  984.0
# 1  654.0    NaN
# 2  899.0    NaN
# 3    NaN    7.0
# 4  989.0   99.0

# %%
df_cleaned=df.dropna(axis=0)
df_cleaned
# Out:
#        A      B
# 0    8.0  984.0
# 4  989.0   99.0

# %%
df_replaced=df.fillna(df.median())
df_replaced
# Out:
#        A      B
# 0    8.0  984.0
# 1  654.0   99.0
# 2  899.0   99.0
# 3  776.5    7.0
# 4  989.0   99.0

# %%
data={'A':[1,2,54,6,7,2,8,6]}
df=pd.DataFrame(data)
df
df_deldup=df.drop_duplicates()
df_deldup
# Out:
#     A
# 0   1
# 1   2
# 2  54
# 3   6
# 4   7
# 6   8

# %%
data={'Height':["Tall","Short","Tall","Medium"]}
df=pd.DataFrame(data)
df
# Out:
#    Height
# 0    Tall
# 1   Short
# 2    Tall
# 3  Medium

# %%
#one-hot encoding
df_enc=pd.get_dum


mies(df,columns=['Height'])
df_enc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 #one-hot encoding
# ----> 2 df_enc=pd.get_dum
#       5 mies(df,columns=['Height'])
#       6 df_enc
#
# AttributeError: module 'pandas' has no attribute 'get_dum'

# %%
df
# Out:
#    Height
# 0    Tall
# 1   Short
# 2    Tall
# 3  Medium

# %%
df['Height']=df['Height'].replace("Tall","Unknown")
df
# Out:
#     Height
# 0  Unknown
# 1    Short
# 2  Unknown
# 3   Medium

# %%
scheme={'Tall':3,'Medium':2,'Short':1}
df['Height']=df['Height'].replace(scheme)
df
# Out:
#     Height
# 0  Unknown
# 1        1
# 2  Unknown
# 3        2

# %%
scheme={'Tall':3,'Medium':2,'Short':1}
df['Height']=df['Height'].replace(scheme)
df
# Out:
#     Height
# 0  Unknown
# 1        1
# 2  Unknown
# 3        2

# %%
print("Hello,world")
# Out:
# Hello,world

# %%
i=10
f=10.5
s="python programming"
print(i,f,s)
# Out:
# 10 10.5 python programming

# %%
var=input("Enter your secret answer")
print("Remember your secret  password is "+var)
# Out:
# Enter your secret answer sakshi
# Remember your secret  password is sakshi

# %%
num=int(input("Enter a large number")

# %%
pip install django==3.0.5
pip install django-widget-tweaks
pip install xhtml2pdf
